# %% [markdown]
# ## __Data 5600: Hwk1a__
#
# <br>
#
# ### __Solutions__
#
#
# ---

# %%
import matplotlib.pyplot as plt

# %%
plt.vlines([0, 1, 2],ymin=[0, 0, 0], ymax=[0.2,.44,.36], lw=4)
plt.ylim([0, 1])
plt.xticks([0,1,2])
plt.title("The PDF of Free Throws")
plt.ylabel("$f(x)$")
plt.xlabel("$x$: free throw success")
plt.show()
